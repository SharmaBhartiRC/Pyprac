# %%
for i in range(1,6):
  for j in range(1,i+1):
    print("*",end=" ")
  print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
class myclass:
  x=5
print(myclass)
p1=myclass()
print(p1.x)
# Out:
# <class '__main__.myclass'>
# 5

# %%
class person:
  def __init__(self,name,age):
    self.name=name
    self.age=age
p1=person("john",36)
print(p1.name)
print(p1.age)
# Out:
# john
# 36

# %%
cars = ["ford","volvo","bmw","desire","farari"] 
x=cars
print(x)
print(len(cars))
for x in cars:
  print(x)
  cars.append("Honda")
  break
cars.pop(1)
cars.remove("desire")
print(cars)
x=len(cars)
print(x)
# Out:
# ['ford', 'volvo', 'bmw', 'desire', 'farari']
# 5
# ford
# ['ford', 'bmw', 'farari', 'Honda']
# 4
