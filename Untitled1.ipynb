# %%
i=1
While i<=10
 Print(I,
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-20aad7cb6609> in <module>
#       1 for a in range (1,20):
# ----> 2   Print(a)
#
# NameError: name 'Print' is not defined
