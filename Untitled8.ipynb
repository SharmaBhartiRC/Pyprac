# %%
# !pip install truth-table-generator
import ttg
table=ttg.Truths(["x","y"],["not(x and y)"],ascendig = Truths
print(table)
# Out:
#   File "<ipython-input-3-c424c05dbaee>", line 4
#     print(table)
#     ^
# SyntaxError: invalid syntax
